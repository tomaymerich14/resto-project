# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_d2 = pd.read_csv('/Users/tomaymerich/code/tomaymerich14/resto-project/raw_data/df_dBourse.csv')
df_d16 =pd.read_csv('/Users/tomaymerich/code/tomaymerich14/resto-project/raw_data/df_DXVI.csv')

# %%
df_d2 = df_d2.drop(columns=['CA_HT', 'TVA'])

# %%
df_d16 = df_d16.drop(columns=['CA_HT', 'TVA'])

# %%
df_d2
# Out:
#             date      jour service   CA_TTC
# 0     2019-01-01     Mardi    soir   8345.0
# 1     2019-01-02  Mercredi    midi   3939.0
# 2     2019-01-02  Mercredi    soir   9045.5
# 3     2019-01-03     Jeudi    midi   4836.0
# 4     2019-01-03     Jeudi    soir  10024.0
# ...          ...       ...     ...      ...
# 1272  2021-08-19     Jeudi    soir   9313.5
# 1273  2021-08-20  Vendredi    midi   2539.0
# 1274  2021-08-20  Vendredi    soir  10948.5
# 1275  2021-08-21    Samedi    midi   3015.0
# 1276  2021-08-21    Samedi    soir  11066.2
#
# [1277 rows x 4 columns]

# %%
df_d16
# Out:
#            date      jour service   CA_TTC
# 0    2019-08-28  Mercredi    soir  1723.75
# 1    2019-08-29     Jeudi    soir  3053.68
# 2    2019-08-30  Vendredi    soir  3779.50
# 3    2019-08-31    Samedi    soir  3747.87
# 4    2019-09-01  Dimanche    midi  3548.00
# ..          ...       ...     ...      ...
# 792  2021-07-30  Vendredi    midi  1361.00
# 793  2021-07-30  Vendredi    soir  7058.00
# 794  2021-07-31    Samedi    midi  1655.50
# 795  2021-07-31    Samedi    soir  8446.00
# 796  2021-08-01  Dimanche    midi  1944.00
#
# [797 rows x 4 columns]

# %%
df_d2[(df_d2.jour == 'Jeudi') & (df_d2.service == 'soir')]['CA_TTC'].mean()
# Out:
# 9866.975108695651

# %%
baseline = pd.DataFrame()

# %%
baseline['jour']=['Lundi','Mardi','Mercredi','Jeudi','Vendredi','Samedi','Dimanche']

# %%
baseline = pd.DataFrame(np.repeat(baseline.values,2,axis=0),columns=['jour'])

# %%
baseline['service']='soir'

# %%
for i in np.linspace(0,12,7):
    baseline['service'][i]='midi'

# %%
baseline
# Out:
#         jour service
# 0      Lundi    midi
# 1      Lundi    soir
# 2      Mardi    midi
# 3      Mardi    soir
# 4   Mercredi    midi
# 5   Mercredi    soir
# 6      Jeudi    midi
# 7      Jeudi    soir
# 8   Vendredi    midi
# 9   Vendredi    soir
# 10    Samedi    midi
# 11    Samedi    soir
# 12  Dimanche    midi
# 13  Dimanche    soir

# %%
j = ['Lundi','Mardi','Mercredi','Jeudi','Vendredi','Samedi','Dimanche']
for jour in j:
    print(jour)
# Out:
# Lundi
# Mardi
# Mercredi
# Jeudi
# Vendredi
# Samedi
# Dimanche

# %%
ser = ['midi','soir']

# %%
baseline_d2 = baseline

# %%
baseline_d16 = baseline

# %%
baseline_d16
# Out:
#         jour service
# 0      Lundi    midi
# 1      Lundi    soir
# 2      Mardi    midi
# 3      Mardi    soir
# 4   Mercredi    midi
# 5   Mercredi    soir
# 6      Jeudi    midi
# 7      Jeudi    soir
# 8   Vendredi    midi
# 9   Vendredi    soir
# 10    Samedi    midi
# 11    Samedi    soir
# 12  Dimanche    midi
# 13  Dimanche    soir

# %%
score_d2 = []

for i in j:  
    print(i)
    for s in ser:
        print(s)
        score_d2.append(df_d2[(df_d2.jour == i) & (df_d2.service == s)]['CA_TTC'].mean())
# Out:
# Lundi
# midi
# soir
# Mardi
# midi
# soir
# Mercredi
# midi
# soir
# Jeudi
# midi
# soir
# Vendredi
# midi
# soir
# Samedi
# midi
# soir
# Dimanche
# midi
# soir

# %%
score_d16 = []

for i in j:  
    print(i)
    for s in ser:
        print(s)
        score_d16.append(df_d16[(df_d16.jour == i) & (df_d16.service == s)]['CA_TTC'].mean())
# Out:
# Lundi
# midi
# soir
# Mardi
# midi
# soir
# Mercredi
# midi
# soir
# Jeudi
# midi
# soir
# Vendredi
# midi
# soir
# Samedi
# midi
# soir
# Dimanche
# midi
# soir

# %%
score_d16
# Out:
# [2675.7830188679245,
#  5570.372641509434,
#  2877.3035714285716,
#  6198.080350877192,
#  3120.4381355932205,
#  6201.458360655737,
#  3295.157894736842,
#  6954.656315789473,
#  3370.729090909091,
#  7271.301967213114,
#  4216.606363636363,
#  7320.5960000000005,
#  4577.3122641509435,
#  4546.194166666667]

# %%
score_d2
# Out:
# [2994.822222222222,
#  7325.895909090908,
#  3430.4501086956525,
#  8642.375326086956,
#  3622.2094505494506,
#  9115.078617021276,
#  3797.86010989011,
#  9866.975108695651,
#  4048.8509782608694,
#  10613.206382978722,
#  4599.9990217391305,
#  11181.739673913044,
#  4217.733522727272,
#  6786.344719101125]

# %%
baseline_d16['moyenne'] =score_d16

# %%
baseline_d16
# Out:
#         jour service      moyenne
# 0      Lundi    midi  2675.783019
# 1      Lundi    soir  5570.372642
# 2      Mardi    midi  2877.303571
# 3      Mardi    soir  6198.080351
# 4   Mercredi    midi  3120.438136
# 5   Mercredi    soir  6201.458361
# 6      Jeudi    midi  3295.157895
# 7      Jeudi    soir  6954.656316
# 8   Vendredi    midi  3370.729091
# 9   Vendredi    soir  7271.301967
# 10    Samedi    midi  4216.606364
# 11    Samedi    soir  7320.596000
# 12  Dimanche    midi  4577.312264
# 13  Dimanche    soir  4546.194167

# %%
baseline_d16.to_csv('/Users/tomaymerich/code/tomaymerich14/resto-project/raw_data/baseline_d16.csv', index=False)

# %%
baseline_d2['moyenne'] = score_d2

# %%
baseline_d2
# Out:
#         jour service       moyenne
# 0      Lundi    midi   2994.822222
# 1      Lundi    soir   7325.895909
# 2      Mardi    midi   3430.450109
# 3      Mardi    soir   8642.375326
# 4   Mercredi    midi   3622.209451
# 5   Mercredi    soir   9115.078617
# 6      Jeudi    midi   3797.860110
# 7      Jeudi    soir   9866.975109
# 8   Vendredi    midi   4048.850978
# 9   Vendredi    soir  10613.206383
# 10    Samedi    midi   4599.999022
# 11    Samedi    soir  11181.739674
# 12  Dimanche    midi   4217.733523
# 13  Dimanche    soir   6786.344719

# %%
baseline_d2.to_csv('/Users/tomaymerich/code/tomaymerich14/resto-project/raw_data/baseline_d2.csv', index=False)

# %%
baseline_d16
# Out:
#         jour service       moyenne
# 0      Lundi    midi   2994.822222
# 1      Lundi    soir   7325.895909
# 2      Mardi    midi   3430.450109
# 3      Mardi    soir   8642.375326
# 4   Mercredi    midi   3622.209451
# 5   Mercredi    soir   9115.078617
# 6      Jeudi    midi   3797.860110
# 7      Jeudi    soir   9866.975109
# 8   Vendredi    midi   4048.850978
# 9   Vendredi    soir  10613.206383
# 10    Samedi    midi   4599.999022
# 11    Samedi    soir  11181.739674
# 12  Dimanche    midi   4217.733523
# 13  Dimanche    soir   6786.344719

# %%
baseline_d2
# Out:
#         jour service       moyenne
# 0      Lundi    midi   2994.822222
# 1      Lundi    soir   7325.895909
# 2      Mardi    midi   3430.450109
# 3      Mardi    soir   8642.375326
# 4   Mercredi    midi   3622.209451
# 5   Mercredi    soir   9115.078617
# 6      Jeudi    midi   3797.860110
# 7      Jeudi    soir   9866.975109
# 8   Vendredi    midi   4048.850978
# 9   Vendredi    soir  10613.206383
# 10    Samedi    midi   4599.999022
# 11    Samedi    soir  11181.739674
# 12  Dimanche    midi   4217.733523
# 13  Dimanche    soir   6786.344719
